# %%
import matplotlib.pyplot as plt

y_1_values 


y_2_values


y_3_values 




# Generating x values as indices of the list
x_values_1 = np.arange(len(y_1_values))
x_values_2 = np.arange(len(y_2_values))
x_values_3 = np.arange(len(y_3_values))


# Function to smooth data using spline interpolation
def smooth_data(x, y):
    x_smooth = np.linspace(x.min(), x.max(), 300)
    spl = make_interp_spline(x, y, k=7)
    y_smooth = spl(x_smooth)
    return x_smooth, y_smooth

# Smoothing the data
x_smooth_1, y_smooth_1 = smooth_data(x_values_1, y_1_values)
x_smooth_2, y_smooth_2 = smooth_data(x_values_2, y_2_values)
x_smooth_3, y_smooth_3 = smooth_data(x_values_3, y_3_values)

# Plotting all the smoothed data
plt.figure(figsize=(6, 6))
plt.plot(x_smooth_1, y_smooth_1, label=r'$\rho$=0.2')
plt.plot(x_smooth_2, y_smooth_2, label=r'$\rho$=1.5')
plt.plot(x_smooth_3, y_smooth_3, label=r'$\rho$=2')


plt.xlabel('Iteration k',fontsize=20)
plt.ylabel(r'$sGW(P^{(k)}) - sGW(P^{*})$',fontsize=20)
plt.legend(fontsize=20)
plt.grid(True)
plt.xticks(np.arange(0, max(len(y_1_values), len(y_2_values), len(y_3_values)), 2))


plt.savefig('Fig6_combined_plot.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 y_1_values
#       6 y_2_values
#       9 y_3_values
#
# NameError: name 'y_1_values' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
y_1_values = [
#0.3108921243826232-10.000836504844429,
10.002610456352578-10.000836504844429,
10.000849018868587-10.000836504844429,
10.00083660942595-10.000836504844429,
10.000836505686445-10.000836504844429,
10.000836504851234-10.000836504844429,
10.000836504844463-10.000836504844429,
10.000836504844415-10.000836504844429,
10.000836504844326-10.000836504844429,
10.000836504844345-10.000836504844429,
10.000836504844466-10.000836504844429,
10.000836504844441-10.000836504844429,
10.00083650484451-10.000836504844429,
10.000836504844258-10.000836504844429,
10.000836504844532-10.000836504844429,
10.00083650484446-10.000836504844429,
10.000836504844415-10.000836504844429,
10.00083650484447-10.000836504844429,
10.00083650484443-10.000836504844429,
10.000836504844429-10.000836504844429
]


y_2_values = [
#3.1426178437139614 - 3.0799737980283983,
3.0994562205617764 - 3.0799737980283983,
3.0888959241598792 - 3.0799737980283983,
3.0842400034746005 - 3.0799737980283983,
3.0815534311388935 - 3.0799737980283983,
3.0802769034126585 - 3.0799737980283983,
3.0800789471111827 - 3.0799737980283983,
3.0800196735718126 - 3.0799737980283983,
3.0799959583624514 - 3.0799737980283983,
3.0799836517760233 - 3.0799737980283983,
3.0799774170971372 - 3.0799737980283983,
3.0799749198528596 - 3.0799737980283983,
3.0799741311539837 - 3.0799737980283983,
3.079973907098785 - 3.0799737980283983,
3.079973839903373 - 3.0799737980283983,
3.0799738160625485 - 3.0799737980283983,
3.079973805819581 - 3.0799737980283983,
3.079973800748521 - 3.0799737980283983,
3.0799737980283983 - 3.0799737980283983
]


y_3_values = [
#0.3108921243826232-0.24107997428829686,
0.3330059548137708-0.24107997428829686,
0.3041401942129951-0.24107997428829686,
0.2678700794563322-0.24107997428829686,
2.063268615815566864e+00-2.063015873111476051e+00,
2.063075515305238028e+00-2.063015873111476051e+00,
2.063027251394669470e+00-2.063015873111476051e+00,
2.063020093146208822e+00-2.063015873111476051e+00,
2.063018078908125830e+00-2.063015873111476051e+00,
2.063017209769655302e+00-2.063015873111476051e+00,
2.063016731860827679e+00-2.063015873111476051e+00,
2.063016427590012913e+00-2.063015873111476051e+00,
2.063016217507789296e+00-2.063015873111476051e+00,
2.063016066363143608e+00-2.063015873111476051e+00,
2.063015955401373613e+00-2.063015873111476051e+00,
2.063015873111476051e+00-2.063015873111476051e+00
]

# Generating x values as indices of the list
x_values_1 = np.arange(len(y_1_values))
x_values_2 = np.arange(len(y_2_values))
x_values_3 = np.arange(len(y_3_values))


# Generating x values as indices of the list
xx_values_1 = np.arange(len(yy_1_values))
xx_values_3 = np.arange(len(yy_3_values))
xx_values_4_8 = np.arange(len(yy_4_8_values))
xx_values_5 = np.arange(len(yy_5_values))
xx_values_7 = np.arange(len(yy_7_values))
xx_values_10 = np.arange(len(yy_10_values))

# Function to smooth data using spline interpolation
def smooth_data(x, y):
    x_smooth = np.linspace(x.min(), x.max(), 300)
    spl = make_interp_spline(x, y, k=7)
    y_smooth = spl(x_smooth)
    return x_smooth, y_smooth

# Smoothing the data
x_smooth_1, y_smooth_1 = smooth_data(x_values_1, y_1_values)
x_smooth_2, y_smooth_2 = smooth_data(x_values_2, y_2_values)
x_smooth_3, y_smooth_3 = smooth_data(x_values_3, y_3_values)

# Smoothing the data
xx_smooth_1, yy_smooth_1 = smooth_data(xx_values_1, yy_1_values)
xx_smooth_3, yy_smooth_3 = smooth_data(xx_values_3, yy_3_values)
xx_smooth_4_8, yy_smooth_4_8 = smooth_data(xx_values_4_8, yy_4_8_values)
xx_smooth_5, yy_smooth_5 = smooth_data(xx_values_5, yy_5_values)
xx_smooth_7, yy_smooth_7 = smooth_data(xx_values_7, yy_7_values)
xx_smooth_10, yy_smooth_10 = smooth_data(xx_values_10, yy_10_values)

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plotting all the smoothed data for z-values
ax1.plot(xx_smooth_1, yy_smooth_1, label=r'$\rho$=1')
ax1.plot(xx_smooth_3, yy_smooth_3, label=r'$\rho$=3')
ax1.plot(xx_smooth_4_8, yy_smooth_4_8, label=r'$\rho$=4.8')
ax1.plot(xx_smooth_5, yy_smooth_5, label=r'$\rho$=5')
ax1.plot(xx_smooth_7, yy_smooth_7, label=r'$\rho$=7')
ax1.plot(xx_smooth_10, yy_smooth_10, label=r'$\rho$=10')
ax1.set_xlabel('Iteration k', fontsize=20)
ax1.set_ylabel(r'$sGW(P^{(k)}) - sGW(P^{*})$', fontsize=20)
ax1.legend(fontsize=20)
ax1.grid(True)
ax1.set_xticks(np.arange(0, max(len(yy_1_values), 
                                len(yy_3_values), 
                                len(yy_4_8_values),
                                len(yy_5_values),
                                len(yy_7_values),
                                len(yy_10_values)), 2))

# Plotting all the smoothed data for y-values
ax2.plot(x_smooth_1, y_smooth_1, label=r'$\rho$=0.2')
ax2.plot(x_smooth_2, y_smooth_2, label=r'$\rho$=1.5')
ax2.plot(x_smooth_3, y_smooth_3, label=r'$\rho$=2')
ax2.set_xlabel('Iteration k', fontsize=20)
ax2.set_ylabel(r'$sGW(P^{(k)}) - sGW(P^{*})$', fontsize=20)
ax2.legend(fontsize=20)
ax2.grid(True)
ax2.set_xticks(np.arange(0, max(len(y_1_values), len(y_2_values), len(y_3_values)), 2))














# Plotting all the smoothed data
plt.figure(figsize=(6, 6))
ax1.plot(xx_smooth_1, yy_smooth_1, label=r'$\rho$=1')
ax1.plot(xx_smooth_3, yy_smooth_3, label=r'$\rho$=3')
ax1.plot(xx_smooth_4_8, yy_smooth_4_8, label=r'$\rho$=4.8')
ax1.plot(xx_smooth_5, yy_smooth_5, label=r'$\rho$=5')
ax1.plot(xx_smooth_7, yy_smooth_7, label=r'$\rho$=7')
ax1.plot(xx_smooth_10, yy_smooth_10, label=r'$\rho$=10')

plt.xlabel('Iteration k',fontsize=20)
plt.ylabel(r'$sGW(P^{(k)}) - sGW(P^{*})$',fontsize=20)
plt.legend(fontsize=20)
plt.grid(True)
plt.xticks(np.arange(0, 18, 2))


plt.savefig('Fig3_combined_plot.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#######

# %%
##########

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

# Provided data points
y_1_values = [
    10.002610456352578-10.000836504844429,
    10.000849018868587-10.000836504844429,
    10.00083660942595-10.000836504844429,
    10.000836505686445-10.000836504844429,
    10.000836504851234-10.000836504844429,
    10.000836504844463-10.000836504844429,
    10.000836504844415-10.000836504844429,
    10.000836504844326-10.000836504844429,
    10.000836504844345-10.000836504844429,
    10.000836504844466-10.000836504844429,
    10.000836504844441-10.000836504844429,
    10.00083650484451-10.000836504844429,
    10.000836504844258-10.000836504844429,
    10.000836504844532-10.000836504844429,
    10.00083650484446-10.000836504844429,
    10.000836504844415-10.000836504844429,
    10.00083650484447-10.000836504844429,
    10.00083650484443-10.000836504844429,
    10.000836504844429-10.000836504844429
]

y_2_values = [
    3.0994562205617764 - 3.0799737980283983,
    3.0888959241598792 - 3.0799737980283983,
    3.0842400034746005 - 3.0799737980283983,
    3.0815534311388935 - 3.0799737980283983,
    3.0802769034126585 - 3.0799737980283983,
    3.0800789471111827 - 3.0799737980283983,
    3.0800196735718126 - 3.0799737980283983,
    3.0799959583624514 - 3.0799737980283983,
    3.0799836517760233 - 3.0799737980283983,
    3.0799774170971372 - 3.0799737980283983,
    3.0799749198528596 - 3.0799737980283983,
    3.0799741311539837 - 3.0799737980283983,
    3.079973907098785 - 3.0799737980283983,
    3.079973839903373 - 3.0799737980283983,
    3.0799738160625485 - 3.0799737980283983,
    3.079973805819581 - 3.0799737980283983,
    3.079973800748521 - 3.0799737980283983,
    3.0799737980283983 - 3.0799737980283983
]

y_3_values = [
    0.3330059548137708-0.24107997428829686,
    0.3041401942129951-0.24107997428829686,
    0.2678700794563322-0.24107997428829686,
    0.24985387699350398-0.24107997428829686,
    0.24503060265269277-0.24107997428829686,
    0.24211912591098061-0.24107997428829686,
    0.24200431844560755-0.24107997428829686,
    0.24194289325529128-0.24107997428829686,
    6.546237784160783946e+00-6.546228985799258382e+00,
    6.546231515488571517e+00-6.546228985799258382e+00,
    6.546229998218960233e+00-6.546228985799258382e+00,
    6.546229426844690558e+00-6.546228985799258382e+00,
    6.546229179902789852e+00-6.546228985799258382e+00,
    6.546229069569532655e+00-6.546228985799258382e+00,
    6.546229020389565889e+00-6.546228985799258382e+00,
    6.546228998921064246e+00-6.546228985799258382e+00,
    6.546228989939319121e+00-6.546228985799258382e+00,
    6.546228986488419110e+00-6.546228985799258382e+00,
    6.546228985409209500e+00-6.546228985799258382e+00,
    6.546228985286596469e+00-6.546228985799258382e+00,
    6.546228985502846598e+00-6.546228985799258382e+00,
    6.546228985799258382e+00-6.546228985799258382e+00
]

yy_7_values = [
    2.912915206399692369e+00-2.912866801121658522e+00,
    2.912885461178112756e+00-2.912866801121658522e+00,
    2.912875370828840627e+00-2.912866801121658522e+00,
    2.912870703449730758e+00-2.912866801121658522e+00,
    2.912868515508737932e+00-2.912866801121658522e+00,
    2.912867531732743043e+00-2.912866801121658522e+00,
    2.912867106017450691e+00-2.912866801121658522e+00,
    2.912866926606220375e+00-2.912866801121658522e+00,
    2.912866852210340696e+00-2.912866801121658522e+00,
    2.912866821646876936e+00-2.912866801121658522e+00,
    2.912866809150897129e+00-2.912866801121658522e+00,
    2.912866804052362202e+00-2.912866801121658522e+00,
    2.912866801971930819e+00-2.912866801121658522e+00,
    2.912866801121658522e+00-2.912866801121658522e+00
]

yy_10_values = [
    2.063675223888838062e+00-2.063015873111476051e+00,
    2.063529718089255560e+00-2.063015873111476051e+00,
    2.063441184843007203e+00-2.063015873111476051e+00,
    2.063268615815566864e+00-2.063015873111476051e+00,
    2.063075515305238028e+00-2.063015873111476051e+00,
    2.063027251394669470e+00-2.063015873111476051e+00,
    2.063020093146208822e+00-2.063015873111476051e+00,
    2.063018078908125830e+00-2.063015873111476051e+00,
    2.063017209769655302e+00-2.063015873111476051e+00,
    2.063016731860827679e+00-2.063015873111476051e+00,
    2.063016427590012913e+00-2.063015873111476051e+00,
    2.063016217507789296e+00-2.063015873111476051e+00,
    2.063016066363143608e+00-2.063015873111476051e+00,
    2.063015955401373613e+00-2.063015873111476051e+00,
    2.063015873111476051e+00-2.063015873111476051e+00
]

# Generating x values as indices of the list
x_values_1 = np.arange(len(y_1_values))
x_values_2 = np.arange(len(y_2_values))
x_values_3 = np.arange(len(y_3_values))

# Generating x values as indices of the list
xx_values_1 = np.arange(len(yy_1_values))
xx_values_3 = np.arange(len(yy_3_values))
xx_values_4_8 = np.arange(len(yy_4_8_values))
xx_values_5 = np.arange(len(yy_5_values))
xx_values_7 = np.arange(len(yy_7_values))
xx_values_10 = np.arange(len(yy_10_values))

# Function to smooth data using spline interpolation
def smooth_data(x, y, k: int = 1):
    x_smooth = np.linspace(x.min(), x.max(), 300)
    spl = make_interp_spline(x, y, k)
    y_smooth = spl(x_smooth)
    return x_smooth, y_smooth

# Smoothing the data
x_smooth_1, y_smooth_1 = smooth_data(x_values_1, y_1_values)
x_smooth_2, y_smooth_2 = smooth_data(x_values_2, y_2_values)
x_smooth_3, y_smooth_3 = smooth_data(x_values_3, y_3_values)

# Smoothing the data
xx_smooth_1, yy_smooth_1 = smooth_data(xx_values_1, yy_1_values)
xx_smooth_3, yy_smooth_3 = smooth_data(xx_values_3, yy_3_values)
xx_smooth_4_8, yy_smooth_4_8 = smooth_data(xx_values_4_8, yy_4_8_values)
xx_smooth_5, yy_smooth_5 = smooth_data(xx_values_5, yy_5_values)
xx_smooth_7, yy_smooth_7 = smooth_data(xx_values_7, yy_7_values)
xx_smooth_10, yy_smooth_10 = smooth_data(xx_values_10, yy_10_values)

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Plotting all the smoothed data for z-values
ax1.plot(xx_smooth_1, yy_smooth_1, label=r'$\rho$=1')
ax1.plot(xx_smooth_3, yy_smooth_3, label=r'$\rho$=3')
ax1.plot(xx_smooth_4_8, yy_smooth_4_8, label=r'$\rho$=4.8')
ax1.plot(xx_smooth_5, yy_smooth_5, label=r'$\rho$=5')
ax1.plot(xx_smooth_7, yy_smooth_7, label=r'$\rho$=7')
ax1.plot(xx_smooth_10, yy_smooth_10, label=r'$\rho$=10')

# Mark the data points with circles
ax1.scatter(xx_values_1, yy_1_values, color='blue')
ax1.scatter(xx_values_3, yy_3_values, color='orange')
ax1.scatter(xx_values_4_8, yy_4_8_values, color='green')
ax1.scatter(xx_values_5, yy_5_values, color='red')
ax1.scatter(xx_values_7, yy_7_values, color='purple')
ax1.scatter(xx_values_10, yy_10_values, color='brown')

ax1.set_xlabel('Iteration k', fontsize=20)
ax1.set_ylabel(r'$sGW(P^{(k)}) - sGW(P^{*})$', fontsize=20)
ax1.legend(fontsize=20)
ax1.grid(True)
ax1.set_xticks(np.arange(0, max(len(yy_1_values), 
                                len(yy_3_values), 
                                len(yy_4_8_values),
                                len(yy_5_values),
                                len(yy_7_values),
                                len(yy_10_values)), 4))
ax1.tick_params(axis='both', which='major', labelsize=25)

# Plotting all the smoothed data for y-values
ax2.plot(x_smooth_1, y_smooth_1, label=r'$\rho$=0.2')
ax2.plot(x_smooth_2, y_smooth_2, label=r'$\rho$=1.5')
ax2.plot(x_smooth_3, y_smooth_3, label=r'$\rho$=2')

# Mark the data points with circles
ax2.scatter(x_values_1, y_1_values, color='blue')
ax2.scatter(x_values_2, y_2_values, color='orange')
ax2.scatter(x_values_3, y_3_values, color='green')

ax2.set_xlabel('Iteration k', fontsize=20)
ax2.set_ylabel(r'$sGW(P^{(k)}) - sGW(P^{*})$', fontsize=20)
ax2.legend(fontsize=20)
ax2.grid(True)
ax2.set_xticks(np.arange(0, max(len(y_1_values), len(y_2_values), len(y_3_values)), 4))
ax2.tick_params(axis='both', which='major', labelsize=25)

# Adjust layout
plt.tight_layout()

# Save plot
plt.savefig('Fig36_combined_plot.png', dpi=300, bbox_inches='tight')

# Show plot
plt.show()

# %%
#######

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# from scipy.interpolate import make_interp_spline

# # Example data (replace with actual values)
# y_1_values = [0.1, 0.2, 0.15, 0.3, 0.25, 0.35, 0.3, 0.4]
# y_2_values = [0.2, 0.3, 0.25, 0.4, 0.35, 0.45, 0.4, 0.5]
# y_3_values = [0.15, 0.25, 0.2, 0.35, 0.3, 0.4, 0.35, 0.45]

# z_1_values = [0.2, 0.3, 0.25, 0.4, 0.35, 0.45, 0.4, 0.5]
# z_2_values = [0.25, 0.35, 0.3, 0.45, 0.4, 0.5, 0.45, 0.55]
# z_3_values = [0.2, 0.3, 0.25, 0.35, 0.3, 0.4, 0.35, 0.45]
# z_4_values = [0.15, 0.25, 0.2, 0.3, 0.25, 0.35, 0.3, 0.4]

# # Generating x values as indices of the list
# x_values_1 = np.arange(len(y_1_values))
# x_values_2 = np.arange(len(y_2_values))
# x_values_3 = np.arange(len(y_3_values))

# x_values_z1 = np.arange(len(z_1_values))
# x_values_z2 = np.arange(len(z_2_values))
# x_values_z3 = np.arange(len(z_3_values))
# x_values_z4 = np.arange(len(z_4_values))

# # Function to smooth data using spline interpolation
# def smooth_data(x, y):
#     x_smooth = np.linspace(x.min(), x.max(), 300)
#     spl = make_interp_spline(x, y, k=3)  # Use k=3 for cubic spline
#     y_smooth = spl(x_smooth)
#     return x_smooth, y_smooth

# # Smoothing the data
# x_smooth_1, y_smooth_1 = smooth_data(x_values_1, y_1_values)
# x_smooth_2, y_smooth_2 = smooth_data(x_values_2, y_2_values)
# x_smooth_3, y_smooth_3 = smooth_data(x_values_3, y_3_values)

# x_smooth_z1, y_smooth_z1 = smooth_data(x_values_z1, z_1_values)
# x_smooth_z2, y_smooth_z2 = smooth_data(x_values_z2, z_2_values)
# x_smooth_z3, y_smooth_z3 = smooth_data(x_values_z3, z_3_values)
# x_smooth_z4, y_smooth_z4 = smooth_data(x_values_z4, z_4_values)

# # Create subplots
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# # Plotting all the smoothed data for y-values
# ax2.plot(x_smooth_1, y_smooth_1, label=r'$\rho$=0.2')
# ax2.plot(x_smooth_2, y_smooth_2, label=r'$\rho$=1.5')
# ax2.plot(x_smooth_3, y_smooth_3, label=r'$\rho$=2')
# ax2.set_xlabel('Iteration k', fontsize=20)
# ax2.set_ylabel(r'$sGW(P^{(k)}) - sGW(P^{*})$', fontsize=20)
# ax2.legend(fontsize=20)
# ax2.grid(True)
# ax2.set_xticks(np.arange(0, max(len(y_1_values), len(y_2_values), len(y_3_values)), 2))

# # Plotting all the smoothed data for z-values
# ax1.plot(x_smooth_z1, y_smooth_z1, label='z_1_values')
# ax1.plot(x_smooth_z2, y_smooth_z2, label='z_2_values')
# ax1.plot(x_smooth_z3, y_smooth_z3, label='z_3_values')
# ax1.plot(x_smooth_z4, y_smooth_z4, label='z_4_values')
# ax1.set_xlabel('Iteration k', fontsize=20)
# ax1.set_ylabel(r'$sGW(P^{(k)}) - sGW(P^{*})$', fontsize=20)
# ax1.legend(fontsize=20)
# ax1.grid(True)
# ax1.set_xticks(np.arange(0, max(len(z_1_values), len(z_2_values), len(z_3_values), len(z_4_values)), 2))

# plt.tight_layout()
# plt.savefig('Fig_combined_plot.png', dpi=300, bbox_inches='tight')
# plt.show()
